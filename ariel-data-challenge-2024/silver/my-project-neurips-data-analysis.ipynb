# %%
import pandas as pd

train = pd.read_csv('/kaggle/input/ariel-data-challenge-2024/train_adc_info.csv')
test = pd.read_csv('/kaggle/input/ariel-data-challenge-2024/test_adc_info.csv')

# %%
from dataprep.eda import create_report

report = create_report(train, title='Train - NeurIPS - Ariel Data Challenge 2024')

# %%
report

# %%
from dataprep.eda import create_report

report = create_report(test, title='Test - NeurIPS - Ariel Data Challenge 2024')

# %%
report
