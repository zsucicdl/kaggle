# %% [markdown]
# # **FOREWORD**

# %% [markdown]
# This kernel downloads the latest available version of lightgbm and xgboost packages for the **UM - Game-Playing Strength of MCTS Variants** competition. <br>
# We download LightGBM 4.5.0 and XgBoost 2.1.1 versions using a requirements.txt file and reuse them in other kernels <br>
# We also download scikit-learn 1.3.2 version for the same <br>

# %%
# %%writefile -a requirements.txt
#
# lightgbm==4.5.0
# xgboost==2.1.1
# numpy==1.26.4
# scipy==1.14.1
# scikit-learn==1.3.2

# %%
try:
    os.mkdir(f"/kaggle/working/Packages")
except:
    pass

# !pip download -q -r requirements.txt -d /kaggle/working/Packages
