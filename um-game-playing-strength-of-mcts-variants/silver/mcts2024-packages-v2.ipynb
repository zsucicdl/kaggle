# %% [markdown]
# # **FOREWORD**

# %% [markdown]
# This kernel downloads the latest available version of the below packages for the **UM - Game-Playing Strength of MCTS Variants** competition. <br>
#
# Packages downloaded with compatible dependencies- <br>
# - LightGBM 4.5.0 <br>
# - XgBoost 2.1.1 <br>
# - Scikit-learn 1.3.2 (currently available in Colab) <br>
# - Scikit-learn 1.5.1 <br>
# - LightAutoML <br>
# - Autogluon 1.1.1 Tabular <br>
# - Ray 2.10.0 <br>
# - Ipywidgets 8.1.5<br>

# %% [markdown]
# ## **LIGHTGBM AND XGBOOST**

# %%
# %%writefile requirements.txt
#
# lightgbm==4.5.0
# xgboost==2.1.1
# numpy==1.26.4
# scipy==1.14.1

# %%
try:
    os.mkdir(f"/kaggle/working/LGBXGB")
except:
    pass

# !pip download -q -r requirements.txt -d /kaggle/working/LGBXGB

# %% [markdown]
# ## **SCIKIT-LEARN**

# %%
# %%writefile requirements.txt
#
# scikit-learn==1.3.2
# numpy==1.26.4
# scipy==1.14.1

# %%
try:
    os.mkdir(f"/kaggle/working/SKlearn132")
except:
    pass

# !pip download -q -r requirements.txt -d /kaggle/working/SKlearn132

# %%
# %%writefile requirements.txt
#
# scikit-learn==1.5.1
# numpy==1.26.4
# scipy==1.14.1

# %%
try:
    os.mkdir(f"/kaggle/working/SKlearn151")
except:
    pass

# !pip download -q -r requirements.txt -d /kaggle/working/SKlearn151

# %% [markdown]
# ## **LIGHTAUTOML**

# %%
try:
    os.mkdir(f"/kaggle/working/LAMA")
except:
    pass

# !pip download -q lightautoml -d /kaggle/working/LAMA

# %% [markdown]
# ## **AUTOGLUON**

# %%
# %%writefile requirements.txt
#
# autogluon.tabular==1.1.1
# ray==2.10.0
# ipywidgets==8.1.5

# %%
try:
    os.mkdir(f"/kaggle/working/AG111")
except:
    pass

# !pip download -q -r requirements.txt -d /kaggle/working/AG111

# %%
# !ls
