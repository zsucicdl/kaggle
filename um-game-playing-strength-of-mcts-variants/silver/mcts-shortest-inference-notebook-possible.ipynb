# %% [markdown]
# # The shortest inference notebook possible
#
# This notebook has two lines of code and produces a submission for the competition.
#
# The notebook can only be so short because all the work is done in [MCTS EDA which makes sense ⭐️⭐️⭐️⭐️⭐️](https://www.kaggle.com/code/ambrosm/mcts-eda-which-makes-sense) (Version 3). The EDA notebook
# 1. analyzes the data
# 1. fits several models
# 1. determines blending weights
# 1. saves the fitted models and the weights to disk so that they can be used here
# 1. writes a file 'inference.py' containing the inference code (see the last cell of the EDA notebook).
#
# The ensemble consists of seven models with weights as shown below.
# ```
#
# Reference
# - Competition [UM - Game-Playing Strength of MCTS Variants](competitions/um-game-playing-strength-of-mcts-variants/)

# %%
directory = '/kaggle/input/mcts-eda-which-makes-sense/'
exec(open(directory + 'inference.py').read())
