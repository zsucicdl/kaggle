# %% [markdown]
# <a id="1"></a>
# # <p style="background-image: url(https://i.postimg.cc/4dsbJ40M/gahag-0102325023-1.png);font-family:camtasia;font-size:120%;color:Black;text-align:center;border-radius:15px 50px; padding:7px">  Import Library</p>

# %%
import ydata_profiling
import numpy as np
import pandas as pd
from ydata_profiling import ProfileReport

# %% [markdown]
# <a id="1"></a>
# # <p style="background-image: url(https://i.postimg.cc/4dsbJ40M/gahag-0102325023-1.png);font-family:camtasia;font-size:120%;color:Black;text-align:center;border-radius:15px 50px; padding:7px">  Sample data acquisition</p>

# %%
df_train = pd.read_csv('/kaggle/input/hms-harmful-brain-activity-classification/train.csv', encoding="shift-jis")
df_train.shape

# %% [markdown]
# <a id="1"></a>
# # <p style="background-image: url(https://i.postimg.cc/4dsbJ40M/gahag-0102325023-1.png);font-family:camtasia;font-size:120%;color:Black;text-align:center;border-radius:15px 50px; padding:7px">  EDA Processing: ProfileReport</p>

# %%
profile_train = ProfileReport(df_train, title="train_prediction-of-tourist-arrivals Report")
profile_train.to_notebook_iframe()
