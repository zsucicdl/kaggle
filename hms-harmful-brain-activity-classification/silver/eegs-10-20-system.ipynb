# %% [markdown]
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/f/fb/EEG_10-10_system_with_additional_information.svg/1024px-EEG_10-10_system_with_additional_information.svg.png)
# [Source - https://en.wikipedia.org/wiki/10%E2%80%9320_system_%28EEG%29](https://en.wikipedia.org/wiki/10%E2%80%9320_system_%28EEG%29)

# %% [markdown]
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/7/70/21_electrodes_of_International_10-20_system_for_EEG.svg/400px-21_electrodes_of_International_10-20_system_for_EEG.svg.png)

# %% [markdown]
# ## Brain activity notebook series
#
# ### [EEGS 10–20 system](https://www.kaggle.com/code/seshurajup/eegs-10-20-system)
# Better understanding eegs 10-20 system
# ### [Missing Eeg_ids Train.csv vs train_eegs [Resolved]](https://www.kaggle.com/code/seshurajup/missing-eeg-ids-in-train-csv-vs-train-eegs-parquet)
# Extra training eggs [Resolved] as we can ignore it
# ### [EDA train.csv](https://www.kaggle.com/code/seshurajup/eda-train-csv)
# Detailed analysis of the train.csv
# ### [Eegs Pairing Analysis & Features](https://www.kaggle.com/code/seshurajup/eegs-pairing-analysis-features)
# Pairing features analysis and build features
# ### [Eegs Target Analysis - Correct way to merge target](https://www.kaggle.com/code/seshurajup/eegs-target-analysis-correct-way-to-merge-target)
# How to choice the target votes for training
# ### [Eegs Train Split (CV)](https://www.kaggle.com/seshurajup/eegs-train-splits-cv)
# generate better train split without patient_id overlap
#
# #### **Upvote my work if it is useful**

# %% [markdown]
# **[Introduction to EEG](https://www.youtube.com/watch?v=XMizSSOejg0&ab_channel=JeremyMoeller)** ( cover details about LL, LP, RP, RL )
# ![](https://www.googleapis.com/download/storage/v1/b/kaggle-forum-message-attachments/o/inbox%2F4308868%2Ff790d9fba9d01f39b5c688819cc90f64%2Ftileshop.jpg?generation=1705166531784497&alt=media)
#
# # Why it called 10-20 system ?
# ![](https://www.googleapis.com/download/storage/v1/b/kaggle-forum-message-attachments/o/inbox%2F761268%2Ff05b56b2adae287e57e1a734a212c846%2FScreenshot%202024-01-14%20at%205.37.01PM.png?generation=1705234054093817&alt=media)
# ![](https://www.googleapis.com/download/storage/v1/b/kaggle-forum-message-attachments/o/inbox%2F761268%2F886f8f291ea118ad878e7828b93f4444%2FScreenshot%202024-01-14%20at%205.37.49PM.png?generation=1705234102821594&alt=media)
#
# # Left Side ( odd numbers ) & Right Side ( even numbers )
# ![](https://www.googleapis.com/download/storage/v1/b/kaggle-forum-message-attachments/o/inbox%2F761268%2F852eadb7e98e79b07ae2b3c6b93be246%2FScreenshot%202024-01-14%20at%205.39.29PM.png?generation=1705234209810764&alt=media)
# ![](https://www.googleapis.com/download/storage/v1/b/kaggle-forum-message-attachments/o/inbox%2F761268%2F707e26f853d0358c5355eac2b8c913ca%2FScreenshot%202024-01-14%20at%205.40.15PM.png?generation=1705234245724252&alt=media)
#
# # Terminology
# * Fz, Cz, Pz --> z stands Zero
# * F, C, P --> Frontal, Central and Parietal ( Front, Center, Back )
#
# # LL
# ![](https://www.googleapis.com/download/storage/v1/b/kaggle-forum-message-attachments/o/inbox%2F761268%2F42abf3341243af65c92c8ba2083b9a79%2FScreenshot%202024-01-14%20at%205.49.27PM.png?generation=1705234855564208&alt=media)
#
# #LP
# ![](https://www.googleapis.com/download/storage/v1/b/kaggle-forum-message-attachments/o/inbox%2F761268%2Fa725bf3a965b4299d0af07f4937216f5%2FScreenshot%202024-01-14%20at%205.49.38PM.png?generation=1705234875852002&alt=media)
#
# # RP
# ![](https://www.googleapis.com/download/storage/v1/b/kaggle-forum-message-attachments/o/inbox%2F761268%2F5869dccab21b6cc3ba7b31e849622d5a%2FScreenshot%202024-01-14%20at%205.50.02PM.png?generation=1705234897860474&alt=media)
#
# # RR
# ![](https://www.googleapis.com/download/storage/v1/b/kaggle-forum-message-attachments/o/inbox%2F761268%2Fa13eff4393d4fc67fbf3a2bc52294553%2FScreenshot%202024-01-14%20at%205.50.12PM.png?generation=1705234918197292&alt=media)
#
# # Common Patterns
# ## Eye Blink
# ![](https://www.googleapis.com/download/storage/v1/b/kaggle-forum-message-attachments/o/inbox%2F761268%2F3e4413a236e04867baf6c456bbd6f105%2FScreenshot%202024-01-14%20at%205.58.09PM.png?generation=1705235422652284&alt=media)
#
# ![](https://www.googleapis.com/download/storage/v1/b/kaggle-forum-message-attachments/o/inbox%2F761268%2F2ac1a4a3bb8ff340cd2b3245383f01c6%2FScreenshot%202024-01-14%20at%206.01.51PM.png?generation=1705235531899318&alt=media)
# ![](https://www.googleapis.com/download/storage/v1/b/kaggle-forum-message-attachments/o/inbox%2F761268%2F2f35f6b81f17bae3ad9bdef46a839fe3%2FScreenshot%202024-01-14%20at%206.02.32PM.png?generation=1705235574626255&alt=media)
#
# [Source Youtube](https://www.youtube.com/watch?v=XMizSSOejg0&ab_channel=JeremyMoeller)

# %%
import pandas as pd
test = pd.read_csv("/kaggle/input/hms-harmful-brain-activity-classification/test.csv")
test

# %%
train = pd.read_csv("/kaggle/input/hms-harmful-brain-activity-classification/train.csv")
train.columns

# %%
eegs = pd.read_parquet('/kaggle/input/hms-harmful-brain-activity-classification/train_eegs/1000913311.parquet')
eegs

# %%
eegs.shape

# %%
spec = pd.read_parquet('/kaggle/input/hms-harmful-brain-activity-classification/train_spectrograms/1000086677.parquet')
spec

# %%
spec.shape

# %%
! pip install eeg_positions

# %%
color_hash = {'Cz': 'khaki',
 'Fpz': 'lightgreen',
 'Fz': 'lightgreen',
 'Pz': 'lightgreen',
 'Oz': 'lightgreen',
 'T7': 'skyblue',
 'C3': 'skyblue',
 'C4': 'skyblue',
 'T8': 'skyblue',
 'Fp2': 'salmon',
 'F8': 'salmon',
 'P8': 'violet',
 'O2': 'violet',
 'Fp1': 'salmon',
 'F7': 'salmon',
 'P7': 'violet',
 'O1': 'violet',
 'F3': 'salmon',
 'F4': 'salmon',
 'P3': 'violet',
 'P4': 'violet'}
from eeg_positions import get_elec_coords, plot_coords
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
coords = get_elec_coords(
    system="1020",
    dim="2d",
)
chans = list(coords['label'])
def egg_index_colors(parse_chans):
    pos, colrs = [],[]
    for i, x in enumerate(chans):
        if x not in parse_chans + ['T7','T8','P7','P8']:
            pos.append(i)
            colrs.append('white')
        else:
            pos.append(i)
            colrs.append(color_hash[x])
    return pos, colrs
parse_chans = list(set(eegs.columns) - set([ 'EKG']))
egg_chans, egg_colors = egg_index_colors(parse_chans)

# %%
from eeg_positions import get_elec_coords, plot_coords
coords = get_elec_coords(
    system="1020",
    dim="2d",
)
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
colors = (
    egg_colors
)

fig, ax = plot_coords(
    coords,
    scatter_kwargs={
        "s": 300, 
        "color": colors,
        "edgecolors": "black", 
        "linewidths": 0.5, 
    },
    text_kwargs={
        "ha": "center",  
        "va": "center",  
        "fontsize": 8, 
    },
)
