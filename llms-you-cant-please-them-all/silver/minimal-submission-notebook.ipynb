# %%
import pandas as pd

# %%
def write_essay(topic: str):
    # ...
    return topic + '? I certainly think so.'

# %%
test_filename = "/kaggle/input/llms-you-cant-please-them-all/test.csv"
submission = [{'id': row.id, 'essay': write_essay(row.topic)}
              for row in pd.read_csv(test_filename).itertuples()]

pd.DataFrame(submission).to_csv("submission.csv", index=False)
print('Saved file submission.csv')
